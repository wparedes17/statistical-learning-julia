# %%
using DataFrames, CSV

df = CSV.read("datasets/advertising.csv", DataFrame)
# Out:
# 200×4 DataFrame
#  Row │ TV       Radio    Newspaper  Sales
#      │ Float64  Float64  Float64    Float64
# ─────┼──────────────────────────────────────
#    1 │   230.1     37.8       69.2     22.1
#    2 │    44.5     39.3       45.1     10.4
#    3 │    17.2     45.9       69.3     12.0
#    4 │   151.5     41.3       58.5     16.5
#    5 │   180.8     10.8       58.4     17.9
#    6 │     8.7     48.9       75.0      7.2
#    7 │    57.5     32.8       23.5     11.8
#    8 │   120.2     19.6       11.6     13.2
#   ⋮  │    ⋮        ⋮         ⋮         ⋮
#  194 │   166.8     42.0        3.6     19.6
#  195 │   149.7     35.6        6.0     17.3
#  196 │    38.2      3.7       13.8      7.6
#  197 │    94.2      4.9        8.1     14.0
#  198 │   177.0      9.3        6.4     14.8
#  199 │   283.6     42.0       66.2     25.5
#  200 │   232.1      8.6        8.7     18.4
#                             185 rows omitted

# %%
using Plots, DataFrames

scatter(df.TV, df.Radio,
xlabel="TV", ylabel="Radio", title="TV vs Radio")

# %%
using Plots, DataFrames

scatter(df.TV, df.Newspaper,
xlabel="TV", ylabel="Newspaper", title="TV vs Newspaper")

# %%
using Plots, DataFrames

scatter(df.TV, df.Sales,
xlabel="TV", ylabel="Sales", title="TV vs Sales")

# %%
using Plots, DataFrames

scatter(df.Radio, df.Newspaper,
xlabel="Radio", ylabel="Newspaper", title="Radio vs Newspaper")

# %%
using Plots, DataFrames

scatter(df.Radio, df.Sales,
xlabel="Radio", ylabel="Sales", title="Radio vs Sales")

# %%
using Plots, DataFrames

scatter(df.Newspaper, df.Sales,
xlabel="Nwespaper", ylabel="Sales", title="Newspaper vs Sales")

# %%
using GLM, DataFrames

modelo = lm(@formula(Sales ~ TV + Radio + Newspaper), df)

print(modelo)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# Sales ~ 1 + TV + Radio + Newspaper
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────
#                    Coef.  Std. Error      t  Pr(>|t|)   Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────────
# (Intercept)  4.62512      0.307501    15.04    <1e-33   4.01869    5.23156
# TV           0.0544458    0.00137519  39.59    <1e-94   0.0517337  0.0571578
# Radio        0.107001     0.00848956  12.60    <1e-26   0.0902586  0.123744
# Newspaper    0.000335658  0.00578806   0.06    0.9538  -0.0110792  0.0117505
# ────────────────────────────────────────────────────────────────────────────
